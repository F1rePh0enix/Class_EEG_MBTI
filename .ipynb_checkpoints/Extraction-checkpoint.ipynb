# %%
import sys
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import pandasql as sql

# %%
db = pd.read_excel('Resultats_EEG.xlsx')

# %%
display(db)
# Out:
#                                 report_id           report_title  \
# 0    cbf47f47-824f-47d9-986f-b78e88eb50fc    10 daily activities
# 1    62afa164-978d-4b42-90d1-1afc421afb00    10 Daily Activities
# 2    fb0d72c8-0acd-4d73-b7c3-0e5574d99b2c    10 daily activities
# 3    9f64cf25-bf0c-4b1d-9581-2a7f0468eaa3    10 daily activities
# 4    df0523f8-04d4-4cd3-a811-2a8a83b1fbdf       Daily activities
# ..                                    ...                    ...
# 975  695ce022-8d7e-4ce4-b21f-34ee0bbaf580            B��n��fices
# 976  0f2d6a60-7e38-4cd8-9acc-575a1c33a20b  Rentrer dans le sujet
# 977  00b06008-1492-40aa-a2a1-e04ab579b979    10 Daily Activities
# 978  00b06008-1492-40aa-a2a1-e04ab579b979    10 Daily Activities
# 979  00b06008-1492-40aa-a2a1-e04ab579b979    10 Daily Activities
#
#     practitioner_first_name practitioner_last_name            started_at  \
# 0                     Dario                  Nardi  2023-05-29T14:00:38Z
# 1                    Darren                    Yee  2024-07-03T18:21:35Z
# 2                     Dario                  Nardi  2023-05-29T13:00:43Z
# 3                     Dario                  Nardi  2023-08-30T04:37:56Z
# 4                    Adrien                Mangeot  2024-04-14T06:23:25Z
# ..                      ...                    ...                   ...
# 975                  Adrien                Mangeot  2024-10-03T21:44:20Z
# 976                  Adrien                Mangeot  2024-10-06T06:59:49Z
# 977                  Darren                    Yee  2024-10-14T22:12:04Z
# 978                  Darren                    Yee  2024-10-14T22:12:04Z
# 979                  Darren                    Yee  2024-10-14T22:12:04Z
#
#      duration                                           channels  \
# 0     1736000  ["FP1","F3","C3","P3","O1","F7","T3","T5","FZ"...
# 1     2049000  ["CZ","FZ","FPZ","FP1","F7","F3","FC1","C3","F...
# 2     1719000  ["FP1","F3","C3","P3","O1","F7","T3","T5","FZ"...
# 3     2659000  ["FP1","F3","C3","P3","O1","F7","T3","T5","FZ"...
# 4     2277000  ["CZ","FZ","FPZ","FP1","F7","F3","FC1","C3","F...
# ..        ...                                                ...
# 975   2237000  ["CZ","FZ","FPZ","FP1","F7","F3","FC1","C3","F...
# 976   1237000  ["CZ","FZ","FPZ","FP1","F7","F3","FC1","C3","F...
# 977   1889000  ["CZ","FZ","FPZ","FP1","F7","F3","FC1","C3","F...
# 978   1889000  ["CZ","FZ","FPZ","FP1","F7","F3","FC1","C3","F...
# 979   1889000  ["CZ","FZ","FPZ","FP1","F7","F3","FC1","C3","F...
#
#      sampling_rate                                           birthday     sex  \
# 0            256.0                                                NaN     NaN
# 1            256.0  Wed Sep 08 2004 00:00:00 GMT+0000 (Coordinated...    MALE
# 2            256.0                                                NaN     NaN
# 3            256.0                                                NaN     NaN
# 4            128.0  Tue Nov 21 1967 00:00:00 GMT+0000 (Coordinated...    MALE
# ..             ...                                                ...     ...
# 975          128.0                                                NaN     NaN
# 976          128.0                                                NaN  FEMALE
# 977          256.0  Sun Aug 14 1988 00:00:00 GMT+0000 (Coordinated...  FEMALE
# 978          256.0  Sun Aug 14 1988 00:00:00 GMT+0000 (Coordinated...  FEMALE
# 979          256.0  Sun Aug 14 1988 00:00:00 GMT+0000 (Coordinated...  FEMALE
#
#      ... average_circuit_hits_social average_circuit_hits_technical  \
# 0    ...                        7277                       8354.667
# 1    ...                   53488.668                      54092.668
# 2    ...                     5305.75                           7045
# 3    ...                     10153.5                      10576.667
# 4    ...                   201.66667                          302.5
# ..   ...                         ...                            ...
# 975  ...                   53380.668                          53685
# 976  ...                   29879.834                      29589.166
# 977  ...         2700-05-01 00:00:00                      2689.6667
# 978  ...                   12246.167                      11975.667
# 979  ...                   55519.168                      55362.168
#
#                               region_hits_circuit_hits  \
# 0    [7041,6564,9155,8216,9598,6939,7468,6702,8441,...
# 1    [55178,54766,54751,52001,53173,53850,55464,525...
# 2    [7831,7481,7422,8310,7879,8085,7238,5310,4947,...
# 3    [10313,9178,10345,8867,9493,9837,10166,9950,11...
# 4    [42,42,35,128,371,40,522,503,366,3,2,36,3,18,2...
# ..                                                 ...
# 975  [52701,53470,52649,49869,51700,51897,54725,540...
# 976  [30954,30562,30410,30059,31725,30285,30104,307...
# 977  [2715,2737,2713,2732,2743,2725,2714,2743,2714,...
# 978  [12356,12129,12168,12156,11361,11985,9672,1282...
# 979  [57007,57152,56292,56591,57018,56339,56678,569...
#
#                                    region_hits_regions  \
# 0    ["FP1","FP2","T3","F4","F8","C3","PZ","O2","O1...
# 1    ["CP1","CP2","CP6","F7","F8","FC1","C3","FZ","...
# 2    ["T3","F8","P3","P4","O1","T5","T6","FP1","FP2...
# 3    ["F8","T6","FP1","F3","C3","P3","O1","F7","T3"...
# 4    ["C3","CP5","FC5","FT9","PO7","C4","CP2","CP6"...
# ..                                                 ...
# 975  ["CP2","F4","FC2","FP1","FPZ","FZ","T7","C3","...
# 976  ["C3","C4","CP1","CP2","CP5","CZ","F4","F7","F...
# 977  ["C3","CP1","O1","O2","P4","PO8","C4","CP2","C...
# 978  ["CP5","FP2","FT10","O1","P7","PO7","T7","C3",...
# 979  ["C3","CP1","O1","O2","P4","PO8","C4","CP2","C...
#
#                                  top_circuit_hits_hits  \
# 0    [1706,1501,1109,921,768,665,614,597,597,597,59...
# 1    [1619,1310,1010,715,711,678,670,669,553,532,51...
# 2    [1288,1159,1043,979,979,850,850,696,696,631,59...
# 3    [1642,1412,1412,1363,1199,1034,690,673,673,657...
# 4    [88,28,25,23,21,20,18,15,14,14,10,10,9,8,8,7,7...
# ..                                                 ...
# 975  [1974,1066,1056,780,720,701,651,631,623,605,56...
# 976  [1073,869,493,427,339,338,292,286,270,270,264,...
# 977  [446,96,49,31,25,23,22,20,20,18,17,15,13,13,12...
# 978  [566,508,329,303,303,301,289,222,189,182,162,1...
# 979  [4585,1277,982,918,748,616,605,595,564,549,473...
#
#                              top_circuit_hits_circuits  \
# 0    ["FP1:FP2","T3:F4:F8","C3:PZ","O2:PZ","O1:F8",...
# 1    ["O2:PO8","O1:PO7","P7:PO7","FT10:T8","P8:PO8"...
# 2    ["T3:F8","P3:P4","O1:P4","T5:T6","T3:T5","FP1:...
# 3    ["F8:T6","FP1:F3:C3:P3:O1:F7:T3:T5:FZ:FP2:F4:C...
# 4    ["P8:PO8","CP2:CP6","CP2:PO8","CP2:CP6:P8:PO8"...
# ..                                                 ...
# 975  ["O1:PO7","O2:PO8","FP2:FPZ","C3:C4:CP1:CP2:CP...
# 976  ["FT10:T7","C3:C4:CP1:CP2:CP5:CP6:CZ:F3:F4:F7:...
# 977  ["C3:C4:CP1:CP2:CP5:CP6:CZ:F3:F4:F8:FC1:FC2:FC...
# 978  ["O1:PO7","O2:PO8","CP6:P8","FP1:FPZ","FP1:FP2...
# 979  ["C3:C4:CP1:CP2:CP5:CP6:CZ:F3:F4:F7:F8:FC1:FC2...
#
#     sampled_data_sampling_rate  \
# 0                            2
# 1                            2
# 2                            2
# 3                            2
# 4                            2
# ..                         ...
# 975                          2
# 976                          2
# 977                          2
# 978                          2
# 979                          2
#
#               sampled_data_max_channel_data_amplitudes  \
# 0    [32.98,32.34,28.41,27.98,22.43,20.38,19.1,30.0...
# 1    [11.752724,8.354612,5.470554,4.1701145,20.9850...
# 2    [16.92,6.22,5.41,7.35,7.48,6.44,5.66,7.74,13.0...
# 3    [21.57,13.7,18.13,14.35,6,2.68,3.32,1.56,2.87,...
# 4    [1.8225476,1.8392375,5.216371,7.9707336,6.8049...
# ..                                                 ...
# 975  [11.699686,25.203989,47.11913,103.459404,19.92...
# 976  [2.4349463,8.501217,4.846262,37.766647,5.33932...
# 977  [18.075312,8.128383,6.693302,14.467537,6.13805...
# 978  [37.597763,17.420996,12.342012,34.87445,122.39...
# 979  [37.597763,17.420996,12.342012,34.87445,122.39...
#
#                 sampled_data_max_channel_data_channels  \
# 0                                                  NaN
# 1    ["FP2","FP1","F4","FC6","FPZ","FPZ","F8","FPZ"...
# 2                                                  NaN
# 3                                                  NaN
# 4    ["FP2","CP6","F3","FP1","CZ","FT9","T8","FC6",...
# ..                                                 ...
# 975  ["T8","FP1","FP1","FP1","FPZ","F3","FC6","FP1"...
# 976  ["CP5","F3","FT9","F7","FT10","PO8","FPZ","FP2...
# 977  ["FP1","T8","T7","FP2","T7","T7","FP2","T7","T...
# 978  ["FP2","FP2","FPZ","FP2","FP2","FP1","FP1","FP...
# 979  ["FP2","FP2","FPZ","FP2","FP2","FP1","FP1","FP...
#
#              sampled_data_max_channel_data_frequencies
# 0    [2,1,2,3,2,3,2,6,6,2,2,2,2,1,2,3,4,3,4,2,2,7,2...
# 1    [2,1,1,3,3,1,1,1,1,3,1,1,1,1,5,3,1,2,1,1,6,1,2...
# 2    [2,3,8,4,2,3,3,4,2,2,2,2,4,2,2,12,11,7,4,5,2,5...
# 3    [2,5,3,2,2,6,2,1,6,2,3,4,2,4,2,2,2,3,4,4,4,3,3...
# 4    [8,14,11,9,10,9,12,12,11,8,10,10,14,9,12,18,19...
# ..                                                 ...
# 975  [2,1,2,1,1,22,1,1,1,1,1,3,1,1,1,7,1,2,1,1,8,3,...
# 976  [36,1,2,1,1,12,12,1,1,1,2,1,1,2,1,1,2,1,1,1,1,...
# 977  [8,29,38,9,39,29,9,33,39,30,36,35,18,32,33,31,...
# 978  [5,1,1,5,1,2,3,1,1,6,3,2,2,1,1,1,2,2,1,3,1,2,1...
# 979  [5,1,1,5,1,2,3,1,39,6,3,2,2,1,1,1,2,30,1,3,1,2...
#
# [980 rows x 38 columns]

# %%
#db.to_pickle('EEG_new.pkl')

# %%
request_col = "SELECT report_title, channels, hand_preference, mbti_type, analysis_version, frequency_bandwidths, executive_style, top_patterns, top_skills, average_circuit_hits_decision_making,average_circuit_hits_perception, average_circuit_hits_abstract, average_circuit_hits_concrete, average_circuit_hits_social, average_circuit_hits_technical, region_hits_circuit_hits, region_hits_regions, top_circuit_hits_hits, top_circuit_hits_circuits"
request_order = " GROUP BY report_title, frequency_bandwidths"
request_where = ' WHERE frequency_bandwidths = ["0.5:45"] '

    
db_filtered = sql.sqldf(request_col + " FROM db" + request_order)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File ~/opt/anaconda3/envs/Finance-QL/lib/python3.11/site-packages/sqlalchemy/engine/base.py:1964, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1963     if not evt_handled:
# -> 1964         self.dialect.do_execute(
#    1965             cursor, str_statement, effective_parameters, context
#    1966         )
#    1968 if self._has_events or self.engine._has_events:
#
# File ~/opt/anaconda3/envs/Finance-QL/lib/python3.11/site-packages/sqlalchemy/engine/default.py:945, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     944 def do_execute(self, cursor, statement, parameters, context=None):
# --> 945     cursor.execute(statement, parameters)
#
# OperationalError: no such column: "0.5:45"
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# File ~/opt/anaconda3/envs/Finance-QL/lib/python3.11/site-packages/pandasql/sqldf.py:61, in PandaSQL.__call__(self, query, env)
#      60 try:
# ---> 61     result = read_sql(query, conn)
#      62 except DatabaseError as ex:
#
# File ~/opt/anaconda3/envs/Finance-QL/lib/python3.11/site-packages/pandas/io/sql.py:734, in read_sql(sql, con, index_col, coerce_float, params, parse_dates, columns, chunksize, dtype_backend, dtype)
#     733 else:
# --> 734     return pandas_sql.read_query(
#     735         sql,
#     736         index_col=index_col,
#     737         params=params,
#     738         coerce_float=coerce_float,
#     739         parse_dates=parse_dates,
#     740         chunksize=chunksize,
#     741         dtype_backend=dtype_backend,
#     742         dtype=dtype,
#     743     )
#
# File ~/opt/anaconda3/envs/Finance-QL/lib/python3.11/site-packages/pandas/io/sql.py:1836, in SQLDatabase.read_query(self, sql, index_col, coerce_float, parse_dates, params, chunksize, dtype, dtype_backend)
#    1790 """
#    1791 Read SQL query into a DataFrame.
#    1792
#    (...)
#    1834
#    1835 """
# -> 1836 result = self.execute(sql, params)
#    1837 columns = result.keys()
#
# File ~/opt/anaconda3/envs/Finance-QL/lib/python3.11/site-packages/pandas/io/sql.py:1659, in SQLDatabase.execute(self, sql, params)
#    1658 if isinstance(sql, str):
# -> 1659     return self.con.exec_driver_sql(sql, *args)
#    1660 return self.con.execute(sql, *args)
#
# File ~/opt/anaconda3/envs/Finance-QL/lib/python3.11/site-packages/sqlalchemy/engine/base.py:1776, in Connection.exec_driver_sql(self, statement, parameters, execution_options)
#    1775 dialect = self.dialect
# -> 1776 ret = self._execute_context(
#    1777     dialect,
#    1778     dialect.execution_ctx_cls._init_statement,
#    1779     statement,
#    1780     None,
#    1781     execution_options,
#    1782     statement,
#    1783     distilled_parameters,
#    1784 )
#    1786 return ret
#
# File ~/opt/anaconda3/envs/Finance-QL/lib/python3.11/site-packages/sqlalchemy/engine/base.py:1843, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1842 else:
# -> 1843     return self._exec_single_context(
#    1844         dialect, context, statement, parameters
#    1845     )
#
# File ~/opt/anaconda3/envs/Finance-QL/lib/python3.11/site-packages/sqlalchemy/engine/base.py:1983, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1982 except BaseException as e:
# -> 1983     self._handle_dbapi_exception(
#    1984         e, str_statement, effective_parameters, cursor, context
#    1985     )
#    1987 return result
#
# File ~/opt/anaconda3/envs/Finance-QL/lib/python3.11/site-packages/sqlalchemy/engine/base.py:2352, in Connection._handle_dbapi_exception(self, e, statement, parameters, cursor, context, is_sub_exec)
#    2351     assert sqlalchemy_exception is not None
# -> 2352     raise sqlalchemy_exception.with_traceback(exc_info[2]) from e
#    2353 else:
#
# File ~/opt/anaconda3/envs/Finance-QL/lib/python3.11/site-packages/sqlalchemy/engine/base.py:1964, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1963     if not evt_handled:
# -> 1964         self.dialect.do_execute(
#    1965             cursor, str_statement, effective_parameters, context
#    1966         )
#    1968 if self._has_events or self.engine._has_events:
#
# File ~/opt/anaconda3/envs/Finance-QL/lib/python3.11/site-packages/sqlalchemy/engine/default.py:945, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     944 def do_execute(self, cursor, statement, parameters, context=None):
# --> 945     cursor.execute(statement, parameters)
#
# OperationalError: (sqlite3.OperationalError) no such column: "0.5:45"
# [SQL: SELECT report_title, channels, hand_preference, mbti_type, analysis_version, frequency_bandwidths, executive_style, top_patterns, top_skills, average_circuit_hits_decision_making,average_circuit_hits_perception, average_circuit_hits_abstract, average_circuit_hits_concrete, average_circuit_hits_social, average_circuit_hits_technical, region_hits_circuit_hits, region_hits_regions, top_circuit_hits_hits, top_circuit_hits_circuits FROM db WHERE frequency_bandwidths = ["0.5:45"]  GROUP BY report_title]
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
#
# During handling of the above exception, another exception occurred:
#
# PandaSQLException                         Traceback (most recent call last)
# Cell In[12], line 6
#       2 request_order = " GROUP BY report_title"
#       3 request_where = ' WHERE frequency_bandwidths = ["0.5:45"] '
# ----> 6 db_filtered = sql.sqldf(request_col + " FROM db" + request_where + request_order)
#
# File ~/opt/anaconda3/envs/Finance-QL/lib/python3.11/site-packages/pandasql/sqldf.py:156, in sqldf(query, env, db_uri)
#     124 def sqldf(query, env=None, db_uri='sqlite:///:memory:'):
#     125     """
#     126     Query pandas data frames using sql syntax
#     127     This function is meant for backward compatibility only. New users are encouraged to use the PandaSQL class.
#    (...)
#     154     >>> sqldf("select avg(x) from df;", locals())
#     155     """
# --> 156     return PandaSQL(db_uri)(query, env)
#
# File ~/opt/anaconda3/envs/Finance-QL/lib/python3.11/site-packages/pandasql/sqldf.py:63, in PandaSQL.__call__(self, query, env)
#      61     result = read_sql(query, conn)
#      62 except DatabaseError as ex:
# ---> 63     raise PandaSQLException(ex)
#      64 except ResourceClosedError:
#      65     # query returns nothing
#      66     result = None
#
# PandaSQLException: (sqlite3.OperationalError) no such column: "0.5:45"
# [SQL: SELECT report_title, channels, hand_preference, mbti_type, analysis_version, frequency_bandwidths, executive_style, top_patterns, top_skills, average_circuit_hits_decision_making,average_circuit_hits_perception, average_circuit_hits_abstract, average_circuit_hits_concrete, average_circuit_hits_social, average_circuit_hits_technical, region_hits_circuit_hits, region_hits_regions, top_circuit_hits_hits, top_circuit_hits_circuits FROM db WHERE frequency_bandwidths = ["0.5:45"]  GROUP BY report_title]
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
